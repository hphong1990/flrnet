# %%
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from keras.layers import *
import tensorflow as tf
import numpy as np
import model_fourier as model
# Out:
# c:\Users\phong\.conda\envs\tf\lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.12.2 when it was built against 1.12.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %% [markdown]
# ## Data preparation

# %%
no_of_sensor = 8
# Prepare field data
Re_list_train = [300, 400, 450, 500, 600, 650, 700, 800, 850, 900, 1000]
Re_list_test = [350, 550, 750, 950]

sensor_data_whole = []
full_field_data_whole = []
for Re in Re_list_train:
    filename = "E:/Research/Data/flow_field_recon/random_sensor_data/sensor_data_" + str(no_of_sensor) + "_" + str(Re) + ".npy"
    sensor_data = np.load(filename)
    sensor_data_whole.append(sensor_data)
    filename_field = "E:/Research/Data/flow_field_recon/full_field_data/full_field_data_" + str(Re) + ".npy"
    full_field_data_whole.append(np.load(filename_field))

sensor_data_whole_array = np.swapaxes(np.concatenate(sensor_data_whole,axis = -1), 0,1)
full_field_data_whole_array = np.swapaxes(
    np.expand_dims(
        np.concatenate(full_field_data_whole, axis = -1), axis = 0),
        0, -1)

print(sensor_data_whole_array.shape)
print(full_field_data_whole_array.shape)

# Normalization

min_val = np.amin(full_field_data_whole_array)
max_val = np.amax(full_field_data_whole_array)
full_field_data_whole_array_norm = (full_field_data_whole_array - min_val)/(max_val - min_val)
sensor_data_whole_array_norm = (sensor_data_whole_array - min_val)/(max_val - min_val)

# Test
print("Check field data: ", np.amin(full_field_data_whole_array_norm), np.amax(full_field_data_whole_array_norm))
print("Check sens data: ", np.amin(sensor_data_whole_array_norm), np.amax(sensor_data_whole_array_norm))

dim = full_field_data_whole_array_norm.shape
x = tf.linspace(0, 1, dim[2])
y = tf.linspace(0, 1, dim[1])
coordX, coordY = np.meshgrid(x, y)
coordX = np.expand_dims(coordX, axis = -1)
coordY = np.expand_dims (coordY, axis = -1)
input_coord = np.concatenate([coordX,coordY], axis = -1)
input_coord = np.repeat(input_coord[np.newaxis,:,:,:], dim[0], axis = 0)
# Create tf.dataset
dataset = tf.data.Dataset.from_tensor_slices((sensor_data_whole_array_norm, full_field_data_whole_array_norm, input_coord))
dataset = dataset.shuffle(buffer_size = 2192) 
dataset = dataset.batch(8)
print(dataset)
# Out:
# (429, 8)
# (429, 128, 256, 1)
# Check field data:  0.0 1.0
# Check sens data:  0.013270650800024661 0.766168138177504
# <BatchDataset element_spec=(TensorSpec(shape=(None, 8), dtype=tf.float64, name=None), TensorSpec(shape=(None, 128, 256, 1), dtype=tf.float64, name=None), TensorSpec(shape=(None, 128, 256, 2), dtype=tf.float64, name=None))>

# %%
input_coord.shape
# Out:
# (429, 128, 256, 2)

# %%
# Prepare sensor data

# %% [markdown]
# ## Training

# %%
tf.keras.backend.clear_session()
flow_recon_net = model.VAE()
flow_recon_net.encoder.load_weights('encoder_fourier.h5')
flow_recon_net.decoder.load_weights('decoder_fourier.h5')
flow_recon_net.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.000005, beta_1 = 0.9, beta_2 = 0.999))
flow_recon_net.fit(dataset, epochs = 100, shuffle = True)

# %%
x = tf.linspace(0, 256, 256)
y = tf.linspace(0,128, 128)
coordX, coordY = tf.meshgrid(x, y)
input_coord = tf.concat([coordX,coordY], axis = -1)

# %%
tf.shape(input_coord)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([128, 512])>

# %%
# Save model weight
flow_recon_net.encoder.save_weights('encoder_fourier.h5')
flow_recon_net.decoder.save_weights('decoder_fourier.h5')

# %%
tf.keras.backend.clear_session()
flow_recon_net = model.FLRNet(n_sensor = no_of_sensor)
flow_recon_net.encoder.load_weights('encoder_fourier.h5')
flow_recon_net.decoder.load_weights('decoder_fourier.h5')
flow_recon_net.sens_mapping.load_weights('mapping_8_ran_fourier.h5')
flow_recon_net.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.00001, beta_1 = 0.9, beta_2 = 0.999))
flow_recon_net.fit(dataset, epochs = 100, shuffle = True)
# Out:
# Epoch 1/100
# 54/54 [==============================] - 4s 40ms/step - loss: 1563.7698 - reconstruction_loss_sens: 918.7729 - kl_loss_sens: 562.2476
# Epoch 2/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1351.8068 - reconstruction_loss_sens: 883.1533 - kl_loss_sens: 512.5824
# Epoch 3/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1388.0211 - reconstruction_loss_sens: 878.6997 - kl_loss_sens: 507.8598
# Epoch 4/100
# 54/54 [==============================] - 2s 41ms/step - loss: 1311.1866 - reconstruction_loss_sens: 878.8598 - kl_loss_sens: 507.5077
# Epoch 5/100
# 54/54 [==============================] - 3s 48ms/step - loss: 1374.3581 - reconstruction_loss_sens: 877.3409 - kl_loss_sens: 507.7997
# Epoch 6/100
# 54/54 [==============================] - 2s 45ms/step - loss: 1286.2353 - reconstruction_loss_sens: 873.8444 - kl_loss_sens: 503.1163
# Epoch 7/100
# 54/54 [==============================] - 2s 43ms/step - loss: 1322.5761 - reconstruction_loss_sens: 873.5475 - kl_loss_sens: 503.1037
# Epoch 8/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1346.8140 - reconstruction_loss_sens: 874.1617 - kl_loss_sens: 502.0031
# Epoch 9/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1373.4280 - reconstruction_loss_sens: 875.8203 - kl_loss_sens: 504.5540
# Epoch 10/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1322.2501 - reconstruction_loss_sens: 874.9405 - kl_loss_sens: 501.6869
# Epoch 11/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1424.0561 - reconstruction_loss_sens: 868.1484 - kl_loss_sens: 498.9467
# Epoch 12/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1318.9184 - reconstruction_loss_sens: 874.7064 - kl_loss_sens: 502.8854
# Epoch 13/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1388.5742 - reconstruction_loss_sens: 870.6812 - kl_loss_sens: 499.0973
# Epoch 14/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1251.7369 - reconstruction_loss_sens: 866.1297 - kl_loss_sens: 497.8110
# Epoch 15/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1326.1100 - reconstruction_loss_sens: 868.3619 - kl_loss_sens: 499.9699
# Epoch 16/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1301.8233 - reconstruction_loss_sens: 872.8072 - kl_loss_sens: 498.9629
# Epoch 17/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1407.6885 - reconstruction_loss_sens: 864.2700 - kl_loss_sens: 497.2680
# Epoch 18/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1424.4976 - reconstruction_loss_sens: 867.4093 - kl_loss_sens: 496.7873
# Epoch 19/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1382.9951 - reconstruction_loss_sens: 865.6074 - kl_loss_sens: 497.8083
# Epoch 20/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1385.3550 - reconstruction_loss_sens: 868.1781 - kl_loss_sens: 497.0883
# Epoch 21/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1353.7213 - reconstruction_loss_sens: 872.1188 - kl_loss_sens: 498.5251
# Epoch 22/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1277.1776 - reconstruction_loss_sens: 866.5512 - kl_loss_sens: 497.7913
# Epoch 23/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1406.5403 - reconstruction_loss_sens: 872.5616 - kl_loss_sens: 499.1864
# Epoch 24/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1420.7804 - reconstruction_loss_sens: 867.0912 - kl_loss_sens: 500.5836
# Epoch 25/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1382.6202 - reconstruction_loss_sens: 865.5464 - kl_loss_sens: 494.3668
# Epoch 26/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1392.5000 - reconstruction_loss_sens: 868.6804 - kl_loss_sens: 496.5710
# Epoch 27/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1307.2268 - reconstruction_loss_sens: 864.5633 - kl_loss_sens: 495.3492
# Epoch 28/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1305.1080 - reconstruction_loss_sens: 863.0357 - kl_loss_sens: 495.4537
# Epoch 29/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1360.5964 - reconstruction_loss_sens: 868.3483 - kl_loss_sens: 500.0861
# Epoch 30/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1375.2103 - reconstruction_loss_sens: 866.5461 - kl_loss_sens: 496.4789
# Epoch 31/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1311.4246 - reconstruction_loss_sens: 862.7296 - kl_loss_sens: 494.3650
# Epoch 32/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1330.8176 - reconstruction_loss_sens: 863.2234 - kl_loss_sens: 495.4872
# Epoch 33/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1344.9870 - reconstruction_loss_sens: 863.6930 - kl_loss_sens: 495.5381
# Epoch 34/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1285.4726 - reconstruction_loss_sens: 865.2232 - kl_loss_sens: 495.5301
# Epoch 35/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1341.5858 - reconstruction_loss_sens: 865.5540 - kl_loss_sens: 500.1935
# Epoch 36/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1333.4069 - reconstruction_loss_sens: 865.3891 - kl_loss_sens: 497.7404
# Epoch 37/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1359.9382 - reconstruction_loss_sens: 864.4998 - kl_loss_sens: 493.8434
# Epoch 38/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1373.8544 - reconstruction_loss_sens: 862.2867 - kl_loss_sens: 495.1126
# Epoch 39/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1320.8231 - reconstruction_loss_sens: 864.6802 - kl_loss_sens: 492.2995
# Epoch 40/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1346.3870 - reconstruction_loss_sens: 861.2193 - kl_loss_sens: 492.6187
# Epoch 41/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1406.7344 - reconstruction_loss_sens: 866.1769 - kl_loss_sens: 495.6101
# Epoch 42/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1382.6593 - reconstruction_loss_sens: 862.4456 - kl_loss_sens: 492.1491
# Epoch 43/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1317.0508 - reconstruction_loss_sens: 863.6882 - kl_loss_sens: 496.3529
# Epoch 44/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1405.1168 - reconstruction_loss_sens: 860.6191 - kl_loss_sens: 494.7920
# Epoch 45/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1312.9953 - reconstruction_loss_sens: 859.4118 - kl_loss_sens: 492.4791
# Epoch 46/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1309.9148 - reconstruction_loss_sens: 863.0134 - kl_loss_sens: 494.0363
# Epoch 47/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1372.5442 - reconstruction_loss_sens: 859.2559 - kl_loss_sens: 491.5215
# Epoch 48/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1323.8149 - reconstruction_loss_sens: 862.5722 - kl_loss_sens: 490.0050
# Epoch 49/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1412.3529 - reconstruction_loss_sens: 864.3735 - kl_loss_sens: 494.7439
# Epoch 50/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1401.9083 - reconstruction_loss_sens: 860.8622 - kl_loss_sens: 491.8134
# Epoch 51/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1372.4094 - reconstruction_loss_sens: 862.7078 - kl_loss_sens: 492.3063
# Epoch 52/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1307.1461 - reconstruction_loss_sens: 861.3405 - kl_loss_sens: 490.3255
# Epoch 53/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1334.7548 - reconstruction_loss_sens: 863.6970 - kl_loss_sens: 493.8922
# Epoch 54/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1383.0039 - reconstruction_loss_sens: 858.8207 - kl_loss_sens: 491.2401
# Epoch 55/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1349.5756 - reconstruction_loss_sens: 863.3934 - kl_loss_sens: 492.8641
# Epoch 56/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1360.2840 - reconstruction_loss_sens: 862.8093 - kl_loss_sens: 492.5379
# Epoch 57/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1325.8717 - reconstruction_loss_sens: 858.1871 - kl_loss_sens: 489.6362
# Epoch 58/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1372.2468 - reconstruction_loss_sens: 862.8398 - kl_loss_sens: 492.2392
# Epoch 59/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1271.8756 - reconstruction_loss_sens: 859.3444 - kl_loss_sens: 491.0439
# Epoch 60/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1369.5499 - reconstruction_loss_sens: 860.4261 - kl_loss_sens: 491.1105
# Epoch 61/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1389.4534 - reconstruction_loss_sens: 860.8530 - kl_loss_sens: 491.7129
# Epoch 62/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1356.4342 - reconstruction_loss_sens: 858.7623 - kl_loss_sens: 490.9491
# Epoch 63/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1331.0417 - reconstruction_loss_sens: 858.6397 - kl_loss_sens: 491.4128
# Epoch 64/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1391.9714 - reconstruction_loss_sens: 857.8487 - kl_loss_sens: 488.2909
# Epoch 65/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1356.7435 - reconstruction_loss_sens: 856.6705 - kl_loss_sens: 488.9021
# Epoch 66/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1379.3956 - reconstruction_loss_sens: 860.4468 - kl_loss_sens: 489.0962
# Epoch 67/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1370.7226 - reconstruction_loss_sens: 860.1378 - kl_loss_sens: 491.8184
# Epoch 68/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1348.5826 - reconstruction_loss_sens: 860.3012 - kl_loss_sens: 488.6381
# Epoch 69/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1343.3132 - reconstruction_loss_sens: 860.5193 - kl_loss_sens: 489.7466
# Epoch 70/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1371.8745 - reconstruction_loss_sens: 858.3671 - kl_loss_sens: 488.4399
# Epoch 71/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1284.7298 - reconstruction_loss_sens: 863.1091 - kl_loss_sens: 492.5358
# Epoch 72/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1291.8146 - reconstruction_loss_sens: 861.9061 - kl_loss_sens: 492.0457
# Epoch 73/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1386.4471 - reconstruction_loss_sens: 859.8814 - kl_loss_sens: 490.3877
# Epoch 74/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1394.9752 - reconstruction_loss_sens: 858.9656 - kl_loss_sens: 488.1978
# Epoch 75/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1388.4572 - reconstruction_loss_sens: 857.9164 - kl_loss_sens: 489.5027
# Epoch 76/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1379.5406 - reconstruction_loss_sens: 859.0352 - kl_loss_sens: 486.5821
# Epoch 77/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1414.1552 - reconstruction_loss_sens: 856.3785 - kl_loss_sens: 488.0762
# Epoch 78/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1355.5077 - reconstruction_loss_sens: 858.0596 - kl_loss_sens: 486.1090
# Epoch 79/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1326.7122 - reconstruction_loss_sens: 855.5070 - kl_loss_sens: 485.9612
# Epoch 80/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1351.6284 - reconstruction_loss_sens: 854.9081 - kl_loss_sens: 487.5912
# Epoch 81/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1311.5801 - reconstruction_loss_sens: 853.5374 - kl_loss_sens: 484.6128
# Epoch 82/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1308.2204 - reconstruction_loss_sens: 858.3011 - kl_loss_sens: 489.3235
# Epoch 83/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1247.8819 - reconstruction_loss_sens: 857.5682 - kl_loss_sens: 488.2912
# Epoch 84/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1314.5752 - reconstruction_loss_sens: 856.1548 - kl_loss_sens: 486.9211
# Epoch 85/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1312.8387 - reconstruction_loss_sens: 855.0594 - kl_loss_sens: 487.6950
# Epoch 86/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1317.6037 - reconstruction_loss_sens: 858.1287 - kl_loss_sens: 487.4716
# Epoch 87/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1330.6211 - reconstruction_loss_sens: 859.7085 - kl_loss_sens: 487.6512
# Epoch 88/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1319.8612 - reconstruction_loss_sens: 855.5762 - kl_loss_sens: 485.7169
# Epoch 89/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1267.4462 - reconstruction_loss_sens: 856.9614 - kl_loss_sens: 486.2576
# Epoch 90/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1299.1504 - reconstruction_loss_sens: 859.1940 - kl_loss_sens: 485.0116
# Epoch 91/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1375.5006 - reconstruction_loss_sens: 857.1176 - kl_loss_sens: 485.2335
# Epoch 92/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1350.0876 - reconstruction_loss_sens: 856.5815 - kl_loss_sens: 486.1093
# Epoch 93/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1383.4414 - reconstruction_loss_sens: 857.1861 - kl_loss_sens: 486.0004
# Epoch 94/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1385.8817 - reconstruction_loss_sens: 853.1660 - kl_loss_sens: 484.1662
# Epoch 95/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1345.6608 - reconstruction_loss_sens: 853.7108 - kl_loss_sens: 483.8382
# Epoch 96/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1283.8023 - reconstruction_loss_sens: 854.2517 - kl_loss_sens: 482.3560
# Epoch 97/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1343.9913 - reconstruction_loss_sens: 858.1578 - kl_loss_sens: 484.6653
# Epoch 98/100
# 54/54 [==============================] - 2s 40ms/step - loss: 1394.4012 - reconstruction_loss_sens: 853.7476 - kl_loss_sens: 485.4651
# Epoch 99/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1363.3007 - reconstruction_loss_sens: 853.2796 - kl_loss_sens: 484.2187
# Epoch 100/100
# 54/54 [==============================] - 2s 39ms/step - loss: 1301.9362 - reconstruction_loss_sens: 853.6028 - kl_loss_sens: 484.2060

# %%
filename = 'mapping_' + str(no_of_sensor) + '_ran_fourier.h5'
flow_recon_net.sens_mapping.save_weights(filename)

# %%
# Save model weight
# Prepare field data

Re_list_train = [300, 400, 450, 500, 600, 650, 700, 800, 850, 900, 1000]
Re_list_test = [350, 550, 750, 950]

sensor_data_whole = []
full_field_data_whole = []
for Re in Re_list_test:
    filename = "E:/Research/Data/flow_field_recon/random_sensor_data/sensor_data_" + str(no_of_sensor) + "_" + str(Re) + ".npy"
    sensor_data = np.load(filename)
    sensor_data_whole.append(sensor_data)
    filename_field = "E:/Research/Data/flow_field_recon/full_field_data/full_field_data_" + str(Re) + ".npy"
    full_field_data_whole.append(np.load(filename_field))

sensor_data_whole_test = np.swapaxes(np.concatenate(sensor_data_whole,axis = -1), 0,1)
full_field_data_whole_test = np.swapaxes(
    np.expand_dims(
        np.concatenate(full_field_data_whole, axis = -1), axis = 0),
        0, -1)

print(sensor_data_whole_test.shape)
print(full_field_data_whole_test.shape)

full_field_data_whole_test_norm = (full_field_data_whole_test - min_val)/(max_val - min_val)
sensor_data_whole_test_norm = (sensor_data_whole_test - min_val)/(max_val - min_val)

# Test
print("Check field data: ", np.amin(full_field_data_whole_test_norm), np.amax(full_field_data_whole_test_norm))
print("Check sens data: ", np.amin(sensor_data_whole_test_norm), np.amax(sensor_data_whole_test_norm))
# Out:
# (156, 8)
# (156, 128, 256, 1)
# Check field data:  0.0 0.9929987273789493
# Check sens data:  0.04263783972866182 0.7515328263773662

# %%
# Save model weight
# Reconstruction
    ## FLRNet
case_idx = 0
_, _, z_sens = flow_recon_net.sens_mapping(sensor_data_whole_test_norm[39*case_idx:(39*(case_idx +1)),:])
reconstruction_sens = flow_recon_net.decoder([z_sens, input_coord[39*case_idx:(39*(case_idx +1)),:,:,:]]).numpy()

# %%
# Save model weight
# Reconstruction
    ## FLRNet
case_idx = 3
_, _, z_sens = flow_recon_net.encoder([full_field_data_whole_test_norm[39*case_idx:(39*(case_idx +1)),:,:,:],input_coord[39*case_idx:(39*(case_idx +1)),:,:,:]])
reconstruction_sens = flow_recon_net.decoder([z_sens, input_coord[39*case_idx:(39*(case_idx +1)),:,:,:]]).numpy()

# %%
import matplotlib.pyplot as plt
for i in range(39):
    _, ax = plt.subplots(2,1)
    ax[0].imshow(reconstruction_sens[i,:,:,0], vmin= 0 ,vmax = 1, cmap = 'Spectral_r')
    ax[0].axis("off")
    ax[1].imshow(full_field_data_whole_test_norm[i+39*case_idx,:,:,0], vmin= 0 ,vmax = 1,cmap = 'Spectral_r')
    ax[1].axis("off")
    plt.show()
